# %%
#this file is a Python Notebok, it needs to be run in kaggle
#it can also work in JupyterLab

#STEPS:
# 1: Open this kernel in a jupyterlab notebook.
# 2: Copy the code onto Kaggle with the same dataset linked.
# 3: run the code through kaggle's notebook (Python).
# 4: It should be runnable.

# the dataset can be found here : https://www.kaggle.com/smid80/weatherww2/data

#importing important libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv("../input/weatherww2/Summary of Weather.csv")
# Out:
# /opt/conda/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (7,8,18,25) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data.head()
# Out:
#      STA      Date Precip  WindGustSpd    MaxTemp    MinTemp   MeanTemp  \
# 0  10001  1942-7-1  1.016          NaN  25.555556  22.222222  23.888889
# 1  10001  1942-7-2      0          NaN  28.888889  21.666667  25.555556
# 2  10001  1942-7-3   2.54          NaN  26.111111  22.222222  24.444444
# 3  10001  1942-7-4   2.54          NaN  26.666667  22.222222  24.444444
# 4  10001  1942-7-5      0          NaN  26.666667  21.666667  24.444444
#
#   Snowfall PoorWeather  YR  ...  FB  FTI ITH  PGT  TSHDSBRSGF  SD3  RHX  RHN  \
# 0        0         NaN  42  ... NaN  NaN NaN  NaN         NaN  NaN  NaN  NaN
# 1        0         NaN  42  ... NaN  NaN NaN  NaN         NaN  NaN  NaN  NaN
# 2        0         NaN  42  ... NaN  NaN NaN  NaN         NaN  NaN  NaN  NaN
# 3        0         NaN  42  ... NaN  NaN NaN  NaN         NaN  NaN  NaN  NaN
# 4        0         NaN  42  ... NaN  NaN NaN  NaN         NaN  NaN  NaN  NaN
#
#   RVG  WTE
# 0 NaN  NaN
# 1 NaN  NaN
# 2 NaN  NaN
# 3 NaN  NaN
# ...

# %%
sns.pairplot(data , x_vars = ['MinTemp'] , y_vars = ['MaxTemp'] , size = 7 , aspect = 0.7 , kind = 'reg')
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/axisgrid.py:2079: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
x_data = data['MinTemp']
y_data = data['MaxTemp']

x = np.array(x_data).reshape(-1, 1)
y = np.array(y_data)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(x,y,random_state = 1)

# %%
print(X_test.shape)
# Out:
# (29760, 1)

# %%
print(y_test.shape)
# Out:
# (29760,)

# %%
from sklearn.linear_model import LinearRegression

# %%
linreg = LinearRegression()
linreg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print(linreg.intercept_)
# Out:
# 10.650603566041713

# %%
print(linreg.coef_)
# Out:
# [0.92160455]

# %%
#drawing training
plt.scatter(X_train, y_train, color= 'black')

plt.plot(X_train, linreg.predict(X_train), color = 'yellow')

plt.title ("Training Dataset")

plt.xlabel("Minimum Temperature")

plt.ylabel("Maximum Temperature")

plt.show()


#drawing test
plt.scatter(X_test, y_test, color= 'black')

plt.plot(X_train, linreg.predict(X_train), color = 'yellow')

plt.title("Testing Dataset")

plt.xlabel("Minimum Temperature")

plt.ylabel("Maximum Temperature")

plt.show()

# %%
import numpy
#finding the mean
x_mean = numpy.mean(x)
print('x_mean :',x_mean)
print()

y_mean = numpy.mean(y)
print('y_mean :',y_mean)
print()


#finding the median
x_median = numpy.median(x)
print('x_median :',x_median)
print()

y_median = numpy.median(y)
print('y_median :',y_median)
print()

from scipy import stats

#finding the mode
x_mode = stats.mode(x)
print('x_mode :',x_mode)
print()

y_mode = stats.mode(y)
print('y_mode :',y_mode)
print()

#finding the standard deviation
x_stdev = numpy.std(x)
print('standard deviation(x)',x_stdev)
print()

y_stdev = numpy.std(y)
print('standard deviation(y)',y_stdev)
print()

#finding the variance
x_var = numpy.var(x)
print('variance(x)',x_var)
print()
y_var = numpy.var(y)
print('variance(y)',x_var)
print()
# Out:
# x_mean : 17.78951052859451
#
# y_mean : 27.045110887087183
#
# x_median : 21.11111111
#
# y_median : 29.44444444
#
# x_mode : ModeResult(mode=array([[22.22222222]]), count=array([[8704]]))
#
# y_mode : ModeResult(mode=array([30.]), count=array([8337]))
#
# standard deviation(x) 8.33453684225561
#
# standard deviation(y) 8.717780031298934
#
# variance(x) 69.46450437491609
#
# variance(y) 69.46450437491609
